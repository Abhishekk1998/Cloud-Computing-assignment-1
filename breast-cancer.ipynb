# %%
import pandas as pd

# %%
ds = pd.read_csv(r"C:\Users\Admin\OneDrive\Desktop\model\data.csv")

# %%
ds.head(30)
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     842302         M       17.990         10.38          122.80     1001.0
# 1     842517         M       20.570         17.77          132.90     1326.0
# 2   84300903         M       19.690         21.25          130.00     1203.0
# 3   84348301         M       11.420         20.38           77.58      386.1
# 4   84358402         M       20.290         14.34          135.10     1297.0
# 5     843786         M       12.450         15.70           82.57      477.1
# 6     844359         M       18.250         19.98          119.60     1040.0
# 7   84458202         M       13.710         20.83           90.20      577.9
# 8     844981         M       13.000         21.82           87.50      519.8
# 9   84501001         M       12.460         24.04           83.97      475.9
# 10    845636         M       16.020         23.24          102.70      797.8
# ...

# %%
target = {'M': 1, 'B': 0}
ds['diagnosis']= ds['diagnosis'].map(target)

# %%
ds.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
ds.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000   0.039769     0.074626      0.099770
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
X = ds.drop(['diagnosis', 'id', 'texture_mean', 'smoothness_mean', 'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'texture_worst', 'smoothness_worst', 'symmetry_worst', 'fractal_dimension_worst'], axis=1)

# %%
X.head()
# Out:
#    radius_mean  perimeter_mean  area_mean  compactness_mean  concavity_mean  \
# 0        17.99          122.80     1001.0           0.27760          0.3001
# 1        20.57          132.90     1326.0           0.07864          0.0869
# 2        19.69          130.00     1203.0           0.15990          0.1974
# 3        11.42           77.58      386.1           0.28390          0.2414
# 4        20.29          135.10     1297.0           0.13280          0.1980
#
#    concave points_mean  radius_se  perimeter_se  area_se  radius_worst  \
# 0              0.14710     1.0950         8.589   153.40         25.38
# 1              0.07017     0.5435         3.398    74.08         24.99
# 2              0.12790     0.7456         4.585    94.03         23.57
# 3              0.10520     0.4956         3.445    27.23         14.91
# 4              0.10430     0.7572         5.438    94.44         22.54
#
#    perimeter_worst  area_worst  compactness_worst  concavity_worst  \
# ...

# %%
Y = ds['diagnosis']

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568    0
# Name: diagnosis, Length: 569, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=5)
print("(X_train, Y_train) = ", (X_train.shape, Y_train.shape))
# Out:
# (X_train, Y_train) =  ((455, 15), (455,))

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
X_train_scale = scale.fit_transform(X_train)
X_test_scale = scale.fit_transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
clf_dt = DecisionTreeClassifier(criterion='entropy', random_state=0)
clf_dt.fit(X_train_scale, Y_train)
Y_pred_dt = clf_dt.predict(X_test_scale)
print("Accuracy score of Decission Tree is ", accuracy_score(Y_test, Y_pred_dt))
# Out:
# Accuracy score of Decission Tree is  0.9298245614035088

# %%
import pickle

# %%
pickle.dump(clf_dt, open('my.pkl', 'wb'))

# %%
X.head(30)
# Out:
#     radius_mean  perimeter_mean  area_mean  compactness_mean  concavity_mean  \
# 0        17.990          122.80     1001.0           0.27760         0.30010
# 1        20.570          132.90     1326.0           0.07864         0.08690
# 2        19.690          130.00     1203.0           0.15990         0.19740
# 3        11.420           77.58      386.1           0.28390         0.24140
# 4        20.290          135.10     1297.0           0.13280         0.19800
# 5        12.450           82.57      477.1           0.17000         0.15780
# 6        18.250          119.60     1040.0           0.10900         0.11270
# 7        13.710           90.20      577.9           0.16450         0.09366
# 8        13.000           87.50      519.8           0.19320         0.18590
# 9        12.460           83.97      475.9           0.23960         0.22730
# 10       16.020          102.70      797.8           0.06669         0.03299
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=20)
classifier.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
Y_pred_dt = classifier.predict(X_test)
print("Accuracy score of Decission Tree is ", accuracy_score(Y_test, Y_pred_dt))
# Out:
# Accuracy score of Decission Tree is  0.956140350877193

# %%
filename = 'ran.pkl'
pickle.dump(classifier, open(filename, 'wb'))

# %%
ds
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
Y_test
# Out:
# 28     1
# 163    0
# 123    0
# 361    0
# 549    0
#       ..
# 414    1
# 515    0
# 186    1
# 3      1
# 261    1
# Name: diagnosis, Length: 114, dtype: int64
